# %%
# !pip install pandas folium geopandas ipyleaflet
# Out:
# Requirement already satisfied: pandas in /Users/ceraven/anaconda3/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: folium in /Users/ceraven/anaconda3/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: geopandas in /Users/ceraven/anaconda3/lib/python3.11/site-packages (1.0.1)
# Requirement already satisfied: ipyleaflet in /Users/ceraven/anaconda3/lib/python3.11/site-packages (0.19.2)
# Requirement already satisfied: numpy>=1.23.2 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: branca>=0.6.0 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from folium) (2024.6.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from geopandas) (24.1)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from geopandas) (2.0.5)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipyleaflet) (8.1.3)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipyleaflet) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipyleaflet) (0.2.1)
# Requirement already satisfied: comm>=0.1.3 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (8.25.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: certifi in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from requests->folium) (2.2.2)
# Requirement already satisfied: decorator in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.15.1)
# Requirement already satisfied: stack-data in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.11.0)
# Requirement already satisfied: pexpect>4.3 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.13)
# Requirement already satisfied: executing in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.3)
# Requirement already satisfied: asttokens in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/ceraven/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.2)

# %%
import pandas as pd

# Step 2: Load the CSV file into a pandas DataFrame
file_path = 'Farmers_Markets_in_Colorado_2017_20241014.csv'  # Adjust the file path as necessary
df = pd.read_csv(file_path)

# Step 3: Select the relevant columns
columns_of_interest = ['name', 'street', 'city', 'zip', 'Day', 'Times', 'dates', 'website', 'facebook', 'long', 'lat']

# Filter the DataFrame to keep only the relevant columns
df_filtered = df[columns_of_interest]
df_filtered.head()  # Show the first few rows
# Out:
#                            name                            street  \
# 0        Boulder Farmers Market  Canyon Boulevard and 13th Street
# 1      Briargate Farmers Market                      7610 N Union
# 2    Edwards CO Farmers' Market                    Edwards Corner
# 3       Glenwood Farmers Market                 1412 Grand Avenue
# 4  Farm and Ranch Market (FARM)               28th & North Avenue
#
#                city      zip                Day             Times  \
# 0           Boulder  80302.0                NaN             Times
# 1  Colorado Springs  80920.0  Wednesday\nSunday  9:00 am - 3:00pm
# 2           Edwards  81632.0                NaN             Times
# 3  Glenwood Springs  81601.0                NaN             Times
# 4    Grand Junction      NaN                NaN             Times
#
#               dates                                         website  \
# 0    May 4 - Oct. 5                             http://www.bcfm.org
# 1  May 31 - Oct. 11  www.springsfarmersmarkets.com/#!briargate/csgz
# 2               NaN             http://www.edwardsfarmersmarket.com
# 3               NaN                                             NaN
# 4               NaN                                             NaN
#
#                                             facebook        long        lat
# 0  www.facebook.com/Boulder-Farmers-Market-512016... -105.277638  40.015245
# 1                                                NaN -104.840856  38.824673
# 2                                                NaN -106.594119  39.644032
# 3  https://www.facebook.com/GlenwoodSpringsFarmer... -107.324839  39.538067
# 4                                                NaN -108.534000  39.077400

# %%
import folium
from folium.plugins import MarkerCluster

# Step 4: Create a map centered in Colorado
map_center = [39.5501, -105.7821]  # Coordinates roughly in the center of Colorado
colorado_map = folium.Map(location=map_center, zoom_start=7)

# Step 5: Add a marker cluster to group nearby farmers markets
marker_cluster = MarkerCluster().add_to(colorado_map)

# Step 6: Loop through the filtered DataFrame and add each market as a marker
for index, row in df_filtered.iterrows():
    name = row['name']
    street = row['street']
    city = row['city']
    zip_code = row['zip']
    lat = row['lat']
    long = row['long']
    day = row['Day']
    times = row['Times']
    dates = row['dates']
    website = row['website']
    facebook = row['facebook']
    
    # Create the popup information
    popup_text = f"""
    <b>{name}</b>
    <br>{street}, {city}, CO {zip_code}<br>
    {day} {times}<br>
    {dates}<br>
    <a href="{website}">{website}</a><br>
    <a href="{facebook}">{facebook}</a>
    """
    
    # Add marker to the cluster with the market details
    folium.Marker(
        location=[lat, long],
        popup=popup_text,
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(marker_cluster)

# Step 7: Display the map
colorado_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d870263318a82e960fdb1b3c818e70c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d870263318a82e960fdb1b3c818e70c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d870263318a82e960fdb1b3c818e70c3 = L.map(
#                 &quot;map_d870263318a82e960fdb1b3c818e70c3&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd570f865f4fdeac6ff6dd82e46cae2f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dd570f865f4fdeac6ff6dd82e46cae2f.addTo(map_d870263318a82e960fdb1b3c818e70c3);
#
#
#             var marker_cluster_a6b477dca17666c966ec63155a4f98d5 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_2fda6ec26c5d3e64a46182038cb5c82d = L.marker(
#                 [40.015245, -105.277638],
#                 {}
#             ).addTo(marker_cluster_a6b477dca17666c966ec63155a4f98d5);
#
#
#             var icon_7ec9bc7b10c671ef6a94c14b74348eaa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2fda6ec26c5d3e64a46182038cb5c82d.setIcon(icon_7ec9bc7b10c671ef6a94c14b74348eaa);
#
#
#         var popup_fe3a8f763a9a8b543e7c3e2f4836dc77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8550662a9bdb652638c69351ef2793a = $(`&lt;div id=&quot;html_a8550662a9bdb652638c69351ef2793a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Boulder Farmers Market&lt;/b&gt;     &lt;br&gt;Canyon Boulevard and 13th Street, Boulder, CO 80302.0&lt;br&gt;     nan Times&lt;br&gt;     May 4 - Oct. 5&lt;br&gt;     &lt;a href=&quot;http://www.bcfm.org&quot;&gt;http://www.bcfm.org&lt;/a&gt;&lt;br&gt;     &lt;a href=&quot;www.facebook.com/Boulder-Farmers-Market-512016698971120&quot;&gt;www.facebook.com/Boulder-Farmers-Market-512016698971120&lt;/a&gt;     &lt;/div&gt;`)[0];
#                 popup_fe3a8f763a9a8b543e7c3e2f4836dc77.setContent(html_a8550662a9bdb652638c69351ef2793a);
#
#
#
#         marker_2fda6ec26c5d3e64a46182038cb5c82d.bindPopup(popup_fe3a8f763a9a8b543e7c3e2f4836dc77)
#         ;
#
#
#
#
#             var marker_1ec3c60d618d6d732ab6e321c516f65d = L.marker(
#                 [38.824673, -104.840856],
#                 {}
#             ).addTo(marker_cluster_a6b477dca17666c966ec63155a4f98d5);
#
#
#             var icon_cee27bdb54078c3c062f80c4cca6ddc8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1ec3c60d618d6d732ab6e321c516f65d.setIcon(icon_cee27bdb54078c3c062f80c4cca6ddc8);
#
#
#         var popup_d53b3b6ca75fab5e0aeaf8b7dbc28195 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d412d47b3543febde8cf0e6b9e2e5d9e = $(`&lt;div id=&quot;html_d412d47b3543febde8cf0e6b9e2e5d9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Briargate Farmers Market&lt;/b&gt;     &lt;br&gt;7610 N Union, Colorado Springs, CO 80920.0&lt;br&gt;     Wednesday Sunday 9:00 am - 3:00pm&lt;br&gt;     May 31 - Oct. 11&lt;br&gt;     &lt;a href=&quot;www.springsfarmersmarkets.com/#!briargate/csgz&quot;&gt;www.springsfarmersmarkets.com/#!briargate/csgz&lt;/a&gt;&lt;br&gt;     &lt;a href=&quot;nan&quot;&gt;nan&lt;/a&gt;     &lt;/div&gt;`)[0];
#                 popup_d53b3b6ca75fab5e0aeaf8b7dbc28195.setContent(html_d412d47b3543febde8cf0e6b9e2e5d9e);
#
#
#
#         marker_1ec3c60d618d6d732ab6e321c516f65d.bindPopup(popup_d53b3b6ca75fab5e0aeaf8b7dbc28195)
#         ;
#
#
#
#
#             var marker_2fa46ff3f25c6d8820a5471cbff0a974 = L.marker(
#                 [39.644032, -106.594119],
#                 {}
#             ).addTo(marker_cluster_a6b477dca17666c966ec63155a4f98d5);
#
#
#             var icon_43ef9ab8ed0b578697610dcecdcfc630 = L.AwesomeM

# %%
# Step 8: Save the map to an HTML file
colorado_map.save('Farmers_Markets_in_Colorado_Map.html')
